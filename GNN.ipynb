# %% [markdown]
# # GNNの勉強頑張ろう
#
# グラフニューラルネットワーク（GNN）は、グラフデータの構造を利用して学習を行う深層学習の一種です。高分子物理の研究においては、分子構造をグラフとして表現し、その特性を予測するためにGNNを使用することができます。
#
# GNNの学習には以下のステップを推奨します：
#
# #### 1.基本的な深層学習の理解
#  GNNを理解するためには、まず基本的な深層学習の概念（ニューラルネットワーク、バックプロパゲーション、活性化関数など）を理解することが重要です。
#
# #### 2.グラフ理論の理解
# GNNはグラフデータに対して動作するため、グラフ理論の基本的な知識が必要です。
#
# #### 3.GNNの理論の理解
# GNNの基本的な理論（グラフ畳み込み、グラフ注意、グラフプーリングなど）を学びます。これには、論文や教科書、オンラインのチュートリアルなどが役立ちます。
#
# #### 4.実装の練習
# 理論を理解したら、実際にGNNを実装してみることが重要です。Pythonの深層学習ライブラリであるPyTorchやTensorFlowは、GNNの実装をサポートする拡張ライブラリ（例えば、PyTorch GeometricやSpektral）を持っています。
#
# #### 5.具体的な問題への適用
# 最後に、具体的な問題（この場合は高分子物理）にGNNを適用します。これには、適切なデータセットの準備と、そのデータセットに対するGNNの訓練と評価が含まれます。

# %% [markdown]
# 具体的な実装例としては、以下にPyTorch Geometricを使用した簡単なGNNの実装例を示します。このコードは、グラフデータを入力として受け取り、各ノードの特徴を更新し、グラフ全体の特徴を出力します。

# %% [markdown]
# # 2.グラフ理論の理解

# %%
# !pip install networkx matplotlib
# Out:
# Requirement already satisfied: networkx in /home/taichi/anaconda3/lib/python3.10/site-packages (2.8.4)
# Requirement already satisfied: matplotlib in /home/taichi/anaconda3/lib/python3.10/site-packages (3.7.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.20 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: six>=1.5 in /home/taichi/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install --upgrade matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/taichi/anaconda3/lib/python3.10/site-packages (3.3.4)
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 17.8 MB/s eta 0:00:00m eta 0:00:010:0101
# Requirement already satisfied: contourpy>=1.0.1 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.20 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: cycler>=0.10 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/taichi/anaconda3/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: six>=1.5 in /home/taichi/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.3.4
#     Uninstalling matplotlib-3.3.4:
#       Successfully uninstalled matplotlib-3.3.4
# Successfully installed matplotlib-3.7.1

# %%
import networkx as nx
import matplotlib.pyplot as plt

# 空のグラフを作成
G = nx.Graph()

# ノードを追加
G.add_node("A")
G.add_node("B")
G.add_node("C")

# エッジを追加
G.add_edge("A", "B")
G.add_edge("A", "C")
G.add_edge("B", "C")

nx.draw_networkx(G)
plt.show()

# %% [markdown]
# ### 空手クラブを使った具体例

# %%
import networkx as nx

# データセットをロード
G = nx.karate_club_graph()

# ノード数とエッジ数を表示
print("Number of nodes: ", G.number_of_nodes())
print("Number of edges: ", G.number_of_edges())
# Out:
# Number of nodes:  34
# Number of edges:  78

# %%
import matplotlib.pyplot as plt

# ネットワークを描画
nx.draw_networkx(G, with_labels=True)
plt.show()

# %%
# 次数中心性を計算
degree_centrality = nx.degree_centrality(G)

# 次数中心性を表示
for node, centrality in degree_centrality.items():
    print(f"Node {node} has degree centrality of {centrality}")
# Out:
# Node 0 has degree centrality of 0.48484848484848486
# Node 1 has degree centrality of 0.2727272727272727
# Node 2 has degree centrality of 0.30303030303030304
# Node 3 has degree centrality of 0.18181818181818182
# Node 4 has degree centrality of 0.09090909090909091
# Node 5 has degree centrality of 0.12121212121212122
# Node 6 has degree centrality of 0.12121212121212122
# Node 7 has degree centrality of 0.12121212121212122
# Node 8 has degree centrality of 0.15151515151515152
# Node 9 has degree centrality of 0.06060606060606061
# Node 10 has degree centrality of 0.09090909090909091
# Node 11 has degree centrality of 0.030303030303030304
# Node 12 has degree centrality of 0.06060606060606061
# Node 13 has degree centrality of 0.15151515151515152
# Node 14 has degree centrality of 0.06060606060606061
# Node 15 has degree centrality of 0.06060606060606061
# Node 16 has degree centrality of 0.06060606060606061
# Node 17 has degree centrality of 0.06060606060606061
# Node 18 has degree centrality of 0.06060606060606061
# Node 19 has degree centrality of 0.09090909090909091
# Node 20 has degree centrality of 0.06060606060606061
# Node 21 has degree centrality of 0.06060606060606061
# Node 22 has degree centrality of 0.06060606060606061
# Node 23 has degree centrality of 0.15151515151515152
# Node 24 has degree centrality of 0.09090909090909091
# Node 25 has degree centrality of 0.09090909090909091
# Node 26 has degree centrality of 0.06060606060606061
# Node 27 has degree centrality of 0.12121212121212122
# Node 28 has degree centrality of 0.09090909090909091
# Node 29 has degree centrality of 0.12121212121212122
# Node 30 has degree centrality of 0.12121212121212122
# Node 31 has degree centrality of 0.18181818181818182
# Node 32 has degree centrality of 0.36363636363636365
# Node 33 has degree centrality of 0.5151515151515151

# %%
# !pip install python-louvain
# Out:
# Collecting python-louvain
#   Downloading python-louvain-0.16.tar.gz (204 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 3.1 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx in /home/taichi/anaconda3/lib/python3.10/site-packages (from python-louvain) (2.8.4)
# Requirement already satisfied: numpy in /home/taichi/anaconda3/lib/python3.10/site-packages (from python-louvain) (1.23.5)
# Building wheels for collected packages: python-louvain
#   Building wheel for python-louvain (setup.py) ... done
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9389 sha256=e2b18c088cfc478e68141acdb2fd9d9bc169ebd7db39954cc2a448c3845d5de4
#   Stored in directory: /home/taichi/.cache/pip/wheels/e0/2c/33/8b5604f69c4a6ed10fb867d51173c03f666920c7c8bbcedbaa
# Successfully built python-louvain
# Installing collected packages: python-louvain
# Successfully installed python-louvain-0.16

# %%
import community as community_louvain

# 最適なパーティションを計算
partition = community_louvain.best_partition(G)

# パーティション（コミュニティ）を表示
for node, community in partition.items():
    print(f"Node {node} belongs to community {community}")
# Out:
# Node 0 belongs to community 0
# Node 1 belongs to community 0
# Node 2 belongs to community 0
# Node 3 belongs to community 0
# Node 4 belongs to community 2
# Node 5 belongs to community 2
# Node 6 belongs to community 2
# Node 7 belongs to community 0
# Node 8 belongs to community 3
# Node 9 belongs to community 3
# Node 10 belongs to community 2
# Node 11 belongs to community 0
# Node 12 belongs to community 0
# Node 13 belongs to community 0
# Node 14 belongs to community 3
# Node 15 belongs to community 3
# Node 16 belongs to community 2
# Node 17 belongs to community 0
# Node 18 belongs to community 3
# Node 19 belongs to community 0
# Node 20 belongs to community 3
# Node 21 belongs to community 0
# Node 22 belongs to community 3
# Node 23 belongs to community 1
# Node 24 belongs to community 1
# Node 25 belongs to community 1
# Node 26 belongs to community 3
# Node 27 belongs to community 1
# Node 28 belongs to community 1
# Node 29 belongs to community 3
# Node 30 belongs to community 3
# Node 31 belongs to community 1
# Node 32 belongs to community 3
# Node 33 belongs to community 3

# %%
import networkx as nx
import matplotlib.pyplot as plt
import community as community_louvain

# ザカリーズの空手クラブネットワークを読み込む
G = nx.karate_club_graph()

# ネットワークの基本情報を表示
print(nx.info(G))

# 平均距離を計算する（連結グラフであることを前提とします）
avg_shortest_path_length = nx.average_shortest_path_length(G)
print(f"Average shortest path length: {avg_shortest_path_length}")

# クラスタリング係数を計算する
avg_clustering_coeff = nx.average_clustering(G)
print(f"Average clustering coefficient: {avg_clustering_coeff}")

# 次数相関を計算する（ネットワーク全体の次数相関係数）
degree_corr = nx.degree_pearson_correlation_coefficient(G)
print(f"Degree correlation: {degree_corr}")

# 中心性を計算する（ノードごとの媒介中心性）
betweenness_centrality = nx.betweenness_centrality(G)
# 媒介中心性が最大のノードを表示
max_bc_node = max(betweenness_centrality, key=betweenness_centrality.get)
print(f"Node with max betweenness centrality: {max_bc_node} ({betweenness_centrality[max_bc_node]})")

# コミュニティ構造を計算する（Louvain法を使用）
partition = community_louvain.best_partition(G)
# コミュニティの数を表示
num_communities = len(set(partition.values()))
print(f"Number of communities: {num_communities}")

# グラフを描画する
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True)
plt.show()
# Out:
# Graph named "Zachary's Karate Club" with 34 nodes and 78 edges
# Average shortest path length: 2.408199643493761
# Average clustering coefficient: 0.5706384782076823
# Degree correlation: -0.47561309768461435
# Node with max betweenness centrality: 0 (0.43763528138528146)
# Number of communities: 4
# /tmp/ipykernel_216075/1323719146.py:9: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   print(nx.info(G))

# %% [markdown]
# グラフニューラルネットの具体例

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /home/taichi/anaconda3/lib/python3.10/site-packages (1.12.1)
# Requirement already satisfied: typing_extensions in /home/taichi/anaconda3/lib/python3.10/site-packages (from torch) (4.4.0)

# %%
# !pip install torch-geometric
# Out:
# Requirement already satisfied: torch-geometric in /home/taichi/anaconda3/lib/python3.10/site-packages (2.3.1)
# Requirement already satisfied: pyparsing in /home/taichi/anaconda3/lib/python3.10/site-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: requests in /home/taichi/anaconda3/lib/python3.10/site-packages (from torch-geometric) (2.28.1)
# Requirement already satisfied: jinja2 in /home/taichi/anaconda3/lib/python3.10/site-packages (from torch-geometric) (3.1.2)
# Requirement already satisfied: numpy in /home/taichi/anaconda3/lib/python3.10/site-packages (from torch-geometric) (1.23.5)
# Requirement already satisfied: scikit-learn in /home/taichi/anaconda3/lib/python3.10/site-packages (from torch-geometric) (1.2.1)
# Requirement already satisfied: scipy in /home/taichi/anaconda3/lib/python3.10/site-packages (from torch-geometric) (1.10.0)
# Requirement already satisfied: psutil>=5.8.0 in /home/taichi/anaconda3/lib/python3.10/site-packages (from torch-geometric) (5.9.0)
# Requirement already satisfied: tqdm in /home/taichi/anaconda3/lib/python3.10/site-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/taichi/anaconda3/lib/python3.10/site-packages (from jinja2->torch-geometric) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/taichi/anaconda3/lib/python3.10/site-packages (from requests->torch-geometric) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/taichi/anaconda3/lib/python3.10/site-packages (from requests->torch-geometric) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/taichi/anaconda3/lib/python3.10/site-packages (from requests->torch-geometric) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/taichi/anaconda3/lib/python3.10/site-packages (from requests->torch-geometric) (1.26.14)
# Requirement already satisfied: joblib>=1.1.1 in /home/taichi/anaconda3/lib/python3.10/site-packages (from scikit-learn->torch-geometric) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/taichi/anaconda3/lib/python3.10/site-packages (from scikit-learn->torch-geometric) (2.2.0)

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.datasets import Planetoid

# データセットをロード
dataset = Planetoid(root='/tmp/Cora', name='Cora')

# GNNの定義
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = GCNConv(dataset.num_node_features, 16)
        self.conv2 = GCNConv(16, dataset.num_classes)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)

        return F.log_softmax(x, dim=1)

# ネットワークとデータを用意
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net().to(device)
data = dataset[0].to(device)

# 最適化手法を定義
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

# モデルの訓練
model.train()
for epoch in range(200):
    optimizer.zero_grad()
    out = model(data)
    loss = F.nll_loss(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.datasets import Planetoid

# データセットをロード
dataset = Planetoid(root='/tmp/Cora', name='Cora')

class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = GCNConv(dataset.num_node_features, 16)
        self.conv2 = GCNConv(16, dataset.num_classes)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, training=self.training)
        x = self.conv2(x, edge_index)

        return F.log_softmax(x, dim=1)

# ネットワークとオプティマイザを設定
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net().to(device)
data = dataset[0].to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

# トレーニングフェーズ
model.train()
for epoch in range(200):
    optimizer.zero_grad()
    out = model(data)
    loss = F.nll_loss(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()

# テストフェーズ
model.eval()
_, pred = model(data).max(dim=1)
correct = float (pred[data.test_mask].eq(data.y[data.test_mask]).sum().item())
acc = correct / data.test_mask.sum().item()
print('Accuracy: {:.4f}'.format(acc))
# Out:
# Accuracy: 0.8000

# %% [markdown]
# # 3.GNNの基本理解
