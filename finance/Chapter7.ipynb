# %% [markdown]
# # 7章：データの可視化

# %% [markdown]
# ## 全体像
# matplotlibやplotlyを使ってデータを可視化する方法を学びます。
#
# https://matplotlib.org/
#
# https://plot.ly/
#
#
# 参考：ロウソク足チャート
#
# https://info.monex.co.jp/technical-analysis/indicators/011.html

# %%
import numpy as np
import pandas as pd

print(np.__version__)
print(pd.__version__)
# Out:
# 1.22.3
# 1.5.2

# %%
import matplotlib as mpl
mpl.__version__
# 教科書は3.0.0なのでそのままだと今後エラーが出る可能性がある
# Out:
# '3.7.1'

# %%
import matplotlib.pyplot as plt

# %%
np.random.seed(1000)

y = np.random.standard_normal(20) # 20個の標準正規分布に従う乱数を生成
x = np.arange(len(y))

plt.plot(x,y)

# %%
plt.plot(y.cumsum())

# %%
raw = pd.read_csv('/home/mori/banzai/machine-learning-phases-of-matter/finance/fxcm_eur_usd_eod_data.csv', index_col=0, parse_dates=True)

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1547 entries, 2013-01-01 22:00:00 to 2017-12-31 22:00:00
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BidOpen   1547 non-null   float64
#  1   BidHigh   1547 non-null   float64
#  2   BidLow    1547 non-null   float64
#  3   BidClose  1547 non-null   float64
#  4   AskOpen   1547 non-null   float64
#  5   AskHigh   1547 non-null   float64
#  6   AskLow    1547 non-null   float64
#  7   AskClose  1547 non-null   float64
# dtypes: float64(8)
# memory usage: 108.8 KB
